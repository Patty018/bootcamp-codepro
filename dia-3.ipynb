# %% [markdown]
# Challenge 1  - 15m,
# Crear una función que imprima la variable palabra.

# %%
def variable():
    print('palabra')

variable()
# Out:
# palabra

# %%
def imprimir_palabra():
    palabra = 'hola'
    print(palabra)
imprimir_palabra()
# Out:
# hola

# %%
#parametros y argumentos

def sumar_numeros(numero1, numero2):
    sumar = numero1 + numero2
    print(sumar)

sumar_numeros(500, 300)
# Out:
# 800

# %% [markdown]
# Challenge 2 🤺 - 15 min
# Crear una función que reciba dos letras (parámetros) y que verifique si son iguales:
#
# Si son iguales, imprimir "Las letras son iguales".
#
# De lo contrario, imprimir "Las letras son diferentes".

# %%
def letras_a_comparar(letra1, letra2):
    if letra1 == letra2:
        print('Las letras son iguales')
    else:
        print('Las letras son diferentes')
      

letras_a_comparar('A', 'A')
# Out:
# Las letras son iguales

# %%
#Funciones con return

def sumar():
    opersacion_suma = 2 + 2
    return opersacion_suma

resultado = sumar()
print(resultado)
# Out:
# 4

# %%
def cajero(cantidad):
    fondos = 100000
    if fondos >= cantidad:
        print(f'el extracto de retiro: {cantidad}')
        fondos = fondos - cantidad
        return cantidad
        
    else:
        prin('fondos insuficientes0')
        return 0
    
extraccion_de_dinero = cajero(110000)
print(f'la cantidad extraida es de: {extracto_de_dinero}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 12
#       9         prin('fondos insuficientes0')
#      10         return 0
# ---> 12 extraccion_de_dinero = cajero(110000)
#      13 print(f'la cantidad extraida es de: {extracto_de_dinero}')
#
# Cell In[33], line 9, in cajero(cantidad)
#       6     return cantidad
#       8 else:
# ----> 9     prin('fondos insuficientes0')
#      10     return 0
#
# NameError: name 'prin' is not defined

# %%
Challenge 3  - 20m,
Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. 
En caso contrario, que retorne False.

imrpimir resultado de la funcion
Pista: cantidad de letras de una palabra en python

# %%
def palabra_igual_a_numero(palabra, numero):
   
    if len(palabra) == numero:
        return 'true'
    
    else:
        return 'false'
    
palabra = input('ingrese una palabra')
numero = int(input('ingrese un numero'))
resultado = palabra_igual_a_numero(palabra, numero)
print(resultado)
# Out:
# true

# %% [markdown]
# Challenge 5  - 25m,
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
#
#
# Ejemplo del resultado esperado:
#
# [['c', 'i', 'e', 'l', 'o']]
#  # Al ingresar la primera palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  # Al ingresar la segunda palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
#  # Al ingresar la tercera palabra

# %%
palabra_ingresada = input('Ingrese una palabra')

cantidad_letras_palabra_ingresada = list(palabra_ingresada)
print(palabra_ingresada)
print(cantidad_letras_palabra_ingresada)
# Out:
# cielo, calor, nubes
# ['c', 'i', 'e', 'l', 'o', ',', ' ', 'c', 'a', 'l', 'o', 'r', ',', ' ', 'n', 'u', 'b', 'e', 's']

# %%
palabras_ingresadas = []

for i in range(3):
    palabra = input("Ingresa una palabra: ")
    lista_caracteres = list(palabra)
    
    palabras_ingresadas.append(lista_caracteres)
    
    print(palabras_ingresadas)
# Out:
# [['c', 'i', 'e', 'l', 'o']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]

# %% [markdown]
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
lista_principal = []
for i in range(3):
     lista = input('ingrese una palabra')
     lista_principal = list(lista)
     
     print(lista_principal)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
lista_principal = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

for i in range(3):
     lista_principal = list(lista)
     
     print(lista_principal)
# Out:
# [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
# [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
# [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# %%
#forma de hacer 1

lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def desglozar_lista(lista):
    for i in range (len(lista)):
        print(lista[i])

desglozar_lista (lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
# configuracion inicial
palabra_secreta = 'gatos'
intentos = 3

# bucle principal
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')

    # logica para verificar la palabra


    intentos = intentos - 1
    print(palabra)

print('ya no quedan intentos')
# Out:
# te quedan 3 intentos
# gatos
# te quedan 2 intentos

# %%
palabra_ingresada = input('ingrese una palabra')
palabra_a_encontrar = 'gatos'

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 6

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
    la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

    if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

    elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

    else:
        letras_verificadas.append(palabra_ingresada[posicion])

        
        return letras_verificadas
    resultado = obtener_fila_verificada(palabra_ingresada, palabra_a_encontrar)
    print(resultado)

# %%
def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es igual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas

resultado = obtener_fila_verificada(palabra_a_encontrar)
print(resultado)

# configuracion inicial
palabra_secreta = 'gatos'
intentos = 3


# bucle principal
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')

    # logica para verificar la palabra


    intentos = intentos - 1
    print(palabra)

print('ya no quedan intentos')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 29
#      24             letras_verificadas.append(palabra_ingresada[posicion])
#      27     return letras_verificadas
# ---> 29 resultado = obtener_fila_verificada(palabra_a_encontrar)
#      30 print(resultado)
#      32 # configuracion inicial
#
# NameError: name 'palabra_a_encontrar' is not defined

# %%
for intento in range(intentos):
    palabra = input(f"Intento {intento+1}: ").lower()

    palabra_ingresada = input('ingrese una palabra')
palabra_a_encontrar = 'gatos'

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 6

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
    la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

    if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

    elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

    else:
        letras_verificadas.append(palabra_ingresada[posicion])

        
        return letras_verificadas
    resultado = obtener_fila_verificada(palabra_ingresada, palabra_a_encontrar)
    print(resultado)
    
    while palabra_ingresada == palabra_a_encontrar:
    if palabra_ingresada == palabra_a_encontrar:
        print("Ganaste")
        break
    else:
         print("Perdiste")
         print("La palabra era", palabra_a_encontrar)
# Out:
#   Cell In[29], line 38
#     if palabra_ingresada == palabra_a_encontrar:
#     ^
# IndentationError: expected an indented block after 'while' statement on line 37

# %%
palabra_ingresada = input('ingrese una palabra')
palabra_a_encontrar = 'gatos'

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 6

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
    la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

    if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

    elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

    else:
        letras_verificadas.append(palabra_ingresada[posicion])

        
        return letras_verificadas
    resultado = obtener_fila_verificada(palabra_ingresada, palabra_a_encontrar)
    print(resultado)

# %%
for intento in range(intentos):
    palabra = input(f"Intento {intento+1}: ").lower()






    palabra_ingresada = input('ingrese una palabra')
palabra_a_encontrar = 'gatos'

# %%
palabra_oculta="gatos"
ingre_pal=input("Ingrese una palabra a comparar: ")
intentos=3


def obtener_fila_verificada():

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range (len(palabra_oculta)): 

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_oculta[posicion] == ingre_pal[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = ingre_pal[posicion] in palabra_oculta

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+ingre_pal[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+ingre_pal[posicion]+')')

        else:
            letras_verificadas.append(ingre_pal[posicion])
resultado = obtener_fila_verificada()
print(resultado)
# Out:
# None

# %%
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')

    palabra_oculta="gatos"
ingre_pal=input("Ingrese una palabra a comparar: ")
intentos=3


def obtener_fila_verificada():

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range (len(palabra_oculta)): 

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_oculta[posicion] == ingre_pal[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = ingre_pal[posicion] in palabra_oculta

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+ingre_pal[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+ingre_pal[posicion]+')')

        else:
            letras_verificadas.append(ingre_pal[posicion])


resultado = obtener_fila_verificada()
print(resultado)


intentos = intentos - 1
print(palabra)


print('ya no quedan intentos')
# Out:
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# te quedan 3 intentos
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 3
#       1 while intentos > 0:
#       2     print(f'te quedan {intentos} intentos')
# ----> 3     palabra = input(' ingrese una palabra')
#       5     palabra_oculta="gatos"
#       6 ingre_pal=input("Ingrese una palabra a comparar: ")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):

# %%
def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas
palabra_para_el_usuario = input('Ingrese su palabra')
palabra_secreta = 'gatos'
resultado = obtener_fila_verificada(palabra_secreta, palabra_para_el_usuario)
print(resultado)

# %%
# configuracion inicial
palabra_secreta = 'gatos'
intentos = 5

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas


# bucle principal
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')
    if palabra == palabra_secreta:
        print("Ganaste")
        break
    else:
        resultado = obtener_fila_verificada(palabra_secreta, palabra)
        print(resultado)
        intentos = intentos - 1
if intentos==0:
    print('ya no quedan intentos')
# Out:
# te quedan 5 intentos
# ['d', '[a]', '[t]', '[o]', '[s]']
# te quedan 4 intentos
# ['p', '[a]', '[t]', '[o]', '[s]']
# te quedan 3 intentos
# ['r', '[a]', '[t]', '[o]', '[s]']
# te quedan 2 intentos

# %%
# configuracion inicial
palabra_secreta = 'gatos'
intentos = 5

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas


# bucle principal
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')
    if palabra == palabra_secreta:
        print("Ganaste")
        break
    else:
        resultado = obtener_fila_verificada(palabra_secreta, palabra)
        print(resultado)
        intentos = intentos - 1
if intentos==0:
    print('ya no quedan intentos')

# %%
# configuracion inicial
palabra_secreta = 'gatos'
intentos = 5

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas


# bucle principal
print('Tienes en total 5 intentos')
while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')
    if palabra == palabra_secreta:
        print("Ganaste")
        break
    else:
        resultado = obtener_fila_verificada(palabra_secreta, palabra)
        print(resultado)
        intentos = intentos - 1
if intentos==0:
    print('ya no quedan intentos')
# Out:
# Tienes en total 5 intentos
# te quedan 5 intentos
# ['m', '[a]', '[t]', 'd', '[s]']
# te quedan 4 intentos
# ['h', '(g)', 'y', '(s)', '(o)']
# te quedan 3 intentos
# ['r', '[a]', '[t]', '(s)', '(o)']
# te quedan 2 intentos
# ['d', '(s)', '(s)', 'f', '(g)']
# te quedan 1 intentos
# ['h', '(g)', '(s)', 'f', '(t)']
# ya no quedan intentos
